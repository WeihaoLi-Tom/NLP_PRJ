# %%
import os
import dotenv
from huggingface_hub import hf_hub_download
dotenv.load_dotenv()
HUGGING_FACE_API_KEY = os.environ.get("HUGGING_FACE_API_KEY")

# %%
model_name = "microsoft/Phi-4-mini-instruct"

# %% [markdown]
# ## Download model ##

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained(model_name, token=HUGGING_FACE_API_KEY)
model = AutoModelForCausalLM.from_pretrained(model_name, token=HUGGING_FACE_API_KEY)
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [01:21<00:00, 40.64s/it]

# %% [markdown]
# ## Save model ##

# %%
tokenizer.save_pretrained(f"tokenizers/{model_name}")
model.save_pretrained(f"models/{model_name}")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained(f"tokenizers/{model_name}")
model = AutoModelForCausalLM.from_pretrained(f"models/{model_name}")
# Out:
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00, 60.60it/s]

# %%
prompt = "Hello, how are you?"

# %%
prompt_embeddings = tokenizer(prompt, return_tensors="pt")
response = model.generate(**prompt_embeddings)

print(response)
print(tokenizer.decode(response[0], skip_special_tokens=True))
# Out:
# tensor([[13225,    11,  1495,   553,   481,    30,   357,   939,  5306,  1775,
#             11, 11172,   481,   395, 16054,    13,   357,   939,  1327,  4113,
#            402,   261,  2993,   484, 23856,  1236]])
# Hello, how are you? I am doing well, thank you for asking. I am just working on a project that involves some
